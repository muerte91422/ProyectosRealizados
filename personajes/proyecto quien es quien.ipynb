# %%
import random
import pygame


# Diccionario de personajes 
personajes = {
    "personaje1": ["pedro", "masculino", "negro", "largo", "rizado", "marrones", True, False, True, True, False, False,
                   True, True, False, "amarillo", True, True, "enfadado", "gruesas", "viejo", False],
    "personaje2": ["fatima", "femenino", "rubio", "corto", "liso", "verdes", False, False, True, False, False, True,
                   True, True, False, "azul", False, True, "asustado", "gruesas", "niño", False],
    "personaje3": ["juan", "masculino", "pelirrojo", "corto", "liso", "azules", False, True, False, False, True, False,
                   False, False, True, "rojo", False, False, "serio", "finas", "joven", True],
    "personaje4": ["ana", "femenino", "negro", "largo", "rizado", "marrones", False, False, True, True, False, False,
                   False, True, False, "negro", True, False, "sonriendo", "gruesas", "viejo", False],
    "personaje5": ["carlos", "masculino", "rubio", "calvo", "liso", "verdes", True, True, False, False, True, False,
                   False, False, True, "azul", False, True, "enfadado", "finas", "niño", True],
    "personaje6": ["maria", "femenino", "pelirrojo", "corto", "rizado", "azules", False, False, True, True, False, False,
                   True, True, False, "amarillo", True, False, "asustado", "gruesas", "joven", False],
    "personaje7": ["luis", "masculino", "negro", "largo", "liso", "marrones", True, False, False, False, True, False,
                   False, False, True, "rojo", False, True, "serio", "finas", "viejo", True],
    "personaje8": ["sofia", "femenino", "rubio", "calvo", "rizado", "verdes", False, True, True, True, False, False,
                   False, True, False, "negro", True, False, "sonriendo", "gruesas", "niño", False],
    "personaje9": ["diego", "masculino", "pelirrojo", "corto", "liso", "azules", True, False, False, False, True, False,
                   True, False, True, "azul", False, True, "enfadado", "finas", "joven", True],
    "personaje10": ["laura", "femenino", "negro", "largo", "rizado", "marrones", False, True, True, False, False, True,
                    False, True, False, "amarillo", True, False, "asustado", "gruesas", "viejo", False],
    "personaje11": ["pablo", "masculino", "rubio", "calvo", "liso", "verdes", True, False, False, False, True, False,
                    False, False, True, "rojo", False, True, "serio", "finas", "niño", True],
    "personaje12": ["elena", "femenino", "pelirrojo", "corto", "rizado", "azules", False, True, True, True, False, False,
                    True, True, False, "negro", True, False, "sonriendo", "gruesas", "joven", False],
    "personaje13": ["javier", "masculino", "negro", "largo", "liso", "azules", True, False, True, True, True, False,
                    False, False, True, "rojo", False, False, "enfadado", "finas", "niño", False],
    "personaje14": ["carmen", "femenino", "negro", "calvo", "liso", "azules", True, True, False, True, True, True,
                    True, True, False, "rojo", True, False, "asustado", "finas", "joven", False],
    "personaje15": ["manuel", "masculino", "pelirrojo", "largo", "liso", "verdes", False, False, True, True, True, True,
                    True, True, False, "azul", True, True, "serio", "gruesas", "niño", True],
    "personaje16": ["isabel", "femenino", "rubio", "corto", "liso", "marrones", True, False, True, False, False, False,
                    False, True, False, "amarillo", True, False, "enfadado", "finas", "joven", False],
    "personaje17": ["antonio", "masculino", "rubio", "calvo", "liso", "verdes", True, False, False, False, True, False,
                    False, False, True, "azul", False, True, "enfadado", "finas", "niño", True],
    "personaje18": ["teresa", "femenino", "pelirrojo", "corto", "rizado", "azules", False, True, True, True, False, False,
                    True, True, False, "amarillo", True, False, "asustado", "gruesas", "joven", False],
    "personaje19": ["francisco", "masculino", "rubio", "calvo", "liso", "verdes", True, False, True, False, True, True,
                    True, False, True, "azul", True, False, "serio", "finas", "viejo", False],
    "personaje20": ["dolores", "femenino", "pelirrojo", "calvo", "liso", "marrones", False, True, False, False, False, True,
                    True, False, True, "azul", True, True, "serio", "finas", "joven", False],
    "personaje21": ["jose", "masculino", "pelirrojo", "calvo", "liso", "verdes", True, True, False, False, False, False,
                    False, False, False, "rojo", False, True, "sonriendo", "finas", "viejo", True],
    "personaje22": ["rosa", "femenino", "pelirrojo", "largo", "liso", "azules", True, False, True, False, False, True,
                    True, False, False, "rojo", True, False, "asustado", "finas", "niño", True],
    "personaje23": ["miguel", "masculino", "rubio", "calvo", "liso", "verdes", True, False, False, False, True, False,
                    False, False, True, "rojo", False, True, "serio", "finas", "niño", True],
    "personaje24": ["pilar", "femenino", "pelirrojo", "corto", "rizado", "azules", False, True, True, True, False, False,
                    True, True, False, "negro", True, False, "sonriendo", "gruesas", "joven", False],
    "personaje25": ["rafael", "masculino", "pelirrojo", "corto", "liso", "verdes", True, True, False, False, True, True,
                    False, True, True, "rojo", False, True, "enfadado", "gruesas", "viejo", False],
    "personaje26": ["encarna", "femenino", "negro", "calvo", "liso", "marrones", False, True, False, False, False, True,
                    False, True, True, "negro", False, False, "sonriendo", "gruesas", "joven", True],
    "personaje27": ["alberto", "masculino", "rubio", "corto", "rizado", "azules", True, False, False, False, False, True,
                    False, True, True, "azul", False, False, "asustado", "finas", "niño", True],
    "personaje28": ["julia", "femenino", "pelirrojo", "largo", "liso", "marrones", True, True, False, True, True, False,
                    False, False, False, "azul", True, True, "enfadado", "gruesas", "viejo", False],
    "personaje29": ["enrique", "masculino", "rubio", "calvo", "liso", "verdes", True, False, False, False, True, False,
                    False, False, True, "azul", False, True, "enfadado", "finas", "niño", True],
    "personaje30": ["cristina", "femenino", "pelirrojo", "corto", "rizado", "azules", False, True, True, True, False, False,
                    True, True, False, "amarillo", True, False, "asustado", "gruesas", "joven", False],
    "personaje31": ["victor", "masculino", "negro", "largo", "liso", "azules", False, False, False, False, True, False,
                    False, False, True, "rojo", True, False, "enfadado", "gruesas", "viejo", True],
    "personaje32": ["beatriz", "femenino", "pelirrojo", "corto", "rizado", "marrones", False, False, True, True, True, True,
                    False, True, True, "rojo", True, False, "enfadado", "finas", "viejo", False],
    "personaje33": ["oscar", "masculino", "negro", "corto", "liso", "azules", True, True, True, True, True, False,
                    False, True, False, "negro", False, True, "asustado", "finas", "niño", False],
    "personaje34": ["raquel", "femenino", "negro", "calvo", "rizado", "azules", False, True, False, True, False, True,
                    True, True, False, "negro", True, True, "enfadado", "gruesas", "joven", False],
    "personaje35": ["sergio", "masculino", "rubio", "calvo", "liso", "verdes", True, False, False, False, True, False,
                    False, False, True, "rojo", False, True, "serio", "finas", "niño", True],
    "personaje36": ["natalia", "femenino", "pelirrojo", "corto", "rizado", "azules", False, True, True, True, False, False,
                    True, True, False, "negro", True, False, "sonriendo", "gruesas", "joven", False],
    "personaje37": ["ruben", "masculino", "rubio", "corto", "liso", "azules", True, False, False, False, True, False,
                    True, True, False, "amarillo", True, False, "asustado", "gruesas", "joven", True],
    "personaje38": ["vanesa", "femenino", "pelirrojo", "largo", "liso", "azules", False, True, True, False, False, True,
                    True, True, False, "azul", False, True, "asustado", "finas", "viejo", False],
    "personaje39": ["ivan", "masculino", "rubio", "calvo", "liso", "marrones", True, False, True, False, False, False,
                    True, False, False, "rojo", True, False, "serio", "finas", "niño", False],
    "personaje40": ["alicia", "femenino", "pelirrojo", "corto", "liso", "marrones", False, True, True, False, False, True,
                    True, True, True, "negro", False, False, "enfadado", "finas", "viejo", True],
    "personaje41": ["andres", "masculino", "rubio", "calvo", "liso", "verdes", True, False, False, False, True, False,
                    False, False, True, "azul", False, True, "enfadado", "finas", "niño", True],
    "personaje42": ["patricia", "femenino", "pelirrojo", "corto", "rizado", "azules", False, True, True, True, False, False,
                    True, True, False, "amarillo", True, False, "asustado", "gruesas", "joven", False],
    "personaje43": ["roberto", "masculino", "rubio", "corto", "liso", "verdes", False, False, False, True, True, True,
                    True, False, True, "azul", True, False, "asustado", "gruesas", "niño", False],
    "personaje44": ["susana", "femenino", "negro", "calvo", "liso", "azules", False, False, True, False, False, False,
                    False, False, True, "negro", False, False, "sonriendo", "finas", "joven", True],
    "personaje45": ["angel", "masculino", "pelirrojo", "corto", "liso", "verdes", True, True, False, False, False, False,
                    False, True, True, "amarillo", True, True, "asustado", "gruesas", "joven", True],
    "personaje46": ["gloria", "femenino", "rubio", "largo", "rizado", "azules", False, True, False, False, False, True,
                    True, True, False, "amarillo", False, True, "serio", "gruesas", "joven", True],
    "personaje47": ["eduardo", "masculino", "rubio", "calvo", "liso", "verdes", True, False, False, False, True, False,
                    False, False, True, "rojo", False, True, "serio", "finas", "niño", True],
    "personaje48": ["cristina", "femenino", "pelirrojo", "corto", "rizado", "azules", False, True, True, True, False, False,
                    True, True, False, "negro", True, False, "sonriendo", "gruesas", "joven", False],
    "personaje49": ["felipe", "masculino", "negro", "largo", "liso", "azules", True, True, True, False, True, False,
                    True, True, True, "amarillo", False, False, "asustado", "gruesas", "viejo", False],
    "personaje50": ["mercedes", "femenino", "negro", "largo", "rizado", "verdes", True, False, False, False, True, False,
                    True, True, True, "amarillo", False, False, "enfadado", "finas", "niño", False]
}
#Primer elemento:nombre,Segundo elemento:sexo,Tercer elemento:color de pelo(negro,rubio o pelirrojo)
#Cuarto elemento:pelo largo , corto o calvo,"Quinto elemento:rizado o liso",sexto elemento: color de ojos(azules, marrones,verdes)
#septimo elemento:tiene barba, octavo elemento:tiene bigote, noveno elemento:tiene pecas,10 elemento:Tiene gafas,
#11 elemento:Tiene sombrero, 12elemento: Tiene gorra, 13 Elmento:tiene diadema, 14 Elemento:Tiene pendientes, 15:tiene Bufanda
#16 elemento:Color de ropa(azul,rojo,amarillo,negro), 17 elemento:Tiene chaqueta, 18 elemento:Tiene corbata, 
#19 elemento:Expresion que hace(serio, sonriendo, enfadado, asustado) 20 elemento: Como tienen cejas(gruesas, finas),
#21 elemento: Edad que tiene(joven, viejo, niño),  22 elemento: Tiene tatuajes


# Palabras clave 
palabras_clave = {
    1: ["masculino", "femenino", "mujer", "hombre", "sexo"],
    2: ["negro", "rubio", "rubia", "pelirrojo", "pelo", "color"],
    3: ["largo", "corto", "calvo", "pelo", "longitud"],
    4: ["rizado", "liso", "pelo", "estilo"],
    5: ["azules", "marrones", "verdes", "azul", "marron", "verde", "ojos", "color"],
    6: ["barba"],
    7: ["bigote"],
    8: ["pecas"],
    9: ["gafas"],
    10: ["sombrero"],
    11: ["gorra"],
    12: ["diadema"],
    13: ["pendientes"],
    14: ["bufanda"],
    15: ["azul", "rojo", "roja", "amarillo", "amarilla", "negro", "negra", "ropa", "color"],
    16: ["chaqueta"],
    17: ["corbata"],
    18: ["serio", "seria", "sonriendo", "enfadado", "asustado", "expresion"],
    19: ["gruesas", "finas", "cejas"],
    20: ["joven", "viejo", "niño", "edad"],
    21: ["tatuajes"]
}

# Lista de preguntas posibles
preguntas_posibles = [
    "1. ¿Es hombre?",
    "2. ¿Es mujer?",
    "3. ¿Tiene el pelo negro?",
    "4. ¿Tiene el pelo rubio?",
    "5. ¿Tiene el pelo pelirrojo?",
    "6. ¿Tiene el pelo corto?",
    "7. ¿Tiene el pelo largo?",
    "8. ¿Está calvo?",
    "9. ¿Tiene el pelo rizado?",
    "10. ¿Tiene el pelo liso?",
    "11. ¿Tiene los ojos azules?",
    "12. ¿Tiene los ojos marrones?",
    "13. ¿Tiene los ojos verdes?",
    "14. ¿Tiene barba?",
    "15. ¿Tiene bigote?",
    "16. ¿Tiene pecas?",
    "17. ¿Tiene gafas?",
    "18. ¿Tiene sombrero?",
    "19. ¿Tiene gorra?",
    "20. ¿Tiene diadema?",
    "21. ¿Tiene pendientes?",
    "22. ¿Tiene bufanda?",
    "23. ¿Su ropa es azul?",
    "24. ¿Su ropa es roja?",
    "25. ¿Su ropa es amarilla?",
    "26. ¿Su ropa es negra?",
    "27. ¿Tiene chaqueta?",
    "28. ¿Tiene corbata?",
    "29. ¿Su expresión es seria?",
    "30. ¿Su expresión es sonriendo?",
    "31. ¿Su expresión es enfadado?",
    "32. ¿Su expresión es asustado?",
    "33. ¿Tiene las cejas gruesas?",
    "34. ¿Tiene las cejas finas?",
    "35. ¿Es joven?",
    "36. ¿Es viejo?",
    "37. ¿Es un niño?",
    "38. ¿Tiene tatuajes?"
]

# Inicializar Pygame
pygame.init()
info = pygame.display.Info()
WIDTH, HEIGHT = info.current_w, info.current_h
screen = pygame.display.set_mode((WIDTH, HEIGHT), pygame.RESIZABLE | pygame.FULLSCREEN)
pygame.display.set_caption("Quién es Quién")
clock = pygame.time.Clock()
font = pygame.font.Font(None, 32)  # Fuente para la entrada
small_font = pygame.font.Font(None, 20)  # Fuente para mensajes

# Seleccionar personaje y restantes
personaje_seleccionado = random.choice(list(personajes.keys()))
remaining = list(personajes.keys())

# Mostrar solo mensajes iniciales sin el personaje seleccionado
messages = ["Bienvenido al juego Quién es Quién.", 
            "Escribe una pregunta (ej. '¿Tiene barba?') y presiona Enter.", 
            "Escribe 'preguntas' para ver ejemplos."]

# Texto del usuario
user_text = ''

# Configuración dinámica del tablero
spacing = 15
min_img_size = 100  # Tamaño mínimo de imagen para calcular columnas
col_count = max(5, (WIDTH - spacing) // (min_img_size + spacing))  # Calcular columnas para aprovechar ancho
num_chars = len(personajes)
row_count = (num_chars - 1) // col_count + 1
img_size = min((WIDTH - (col_count + 1) * spacing) // col_count, (HEIGHT * 6 // 10 - (row_count + 1) * spacing) // row_count)  # 60% altura para espacio de mensajes

# Cargar imágenes y posiciones
char_images = {}
positions = {}
for i, char in enumerate(sorted(personajes.keys())):
    img = pygame.image.load(f"{char}.png")
    img = pygame.transform.scale(img, (img_size, img_size))
    char_images[char] = img
    col = i % col_count
    row = i // col_count
    x = col * (img_size + spacing) + spacing
    y = row * (img_size + spacing) + spacing
    positions[char] = (x, y)

# Altura del tablero
board_height = row_count * (img_size + spacing) + spacing

# Posiciones ajustadas
input_y = board_height  # Pegado justo debajo del tablero
input_height = 50  # Reducido un poco para ahorrar espacio
messages_y_start = input_y + input_height + 5  # Pegado justo debajo del input
line_height = 22  # Ajustado para más líneas

def process_input(escrito):
    global remaining, messages, user_text
    escrito = escrito.lower()
    if len(remaining) == 1 and escrito == "salir":
        pygame.quit()
        running = False
        return

    if escrito == "preguntas":
        messages.append("Lista de preguntas posibles (agrupadas):")
        grouped = []
        for i in range(0, len(preguntas_posibles), 4):
            group = ' '.join(preguntas_posibles[i:i+4])
            grouped.append(group)
        messages.extend(grouped)
        return

    palabras = escrito.split()
    elegida = 0

    # Buscar si "pelo" está presente para activar la búsqueda de atributos de longitud/estilo
    if "pelo" in palabras:
        for i, palabra in enumerate(palabras):
            if palabra in ["corto", "largo", "calvo", "rizado", "liso"]:  # Atributos de longitud/estilo
                if i > 0 and palabras[i-1] == "pelo":  # Verifica si "pelo" precede al atributo
                    if palabra in ["corto", "largo", "calvo"]:
                        elegida = 3  # Longitud de pelo
                    elif palabra in ["rizado", "liso"]:
                        elegida = 4  # Estilo de pelo
                    break
            elif palabra in ["tiene"] and i + 2 < len(palabras) and palabras[i+1] == "el" and palabras[i+2] in ["corto", "largo", "calvo", "rizado", "liso"]:
                if palabras[i+2] in ["corto", "largo", "calvo"]:
                    elegida = 3
                elif palabras[i+2] in ["rizado", "liso"]:
                    elegida = 4
                break

    # Si no se detectó con "pelo", buscar en palabras_clave como fallback
    if elegida == 0:
        for palabra in palabras:
            for posicion, lista_clave in palabras_clave.items():
                if palabra in lista_clave:
                    elegida = posicion
                    break
            if elegida:
                break

    if elegida == 0:
        messages.append("La pregunta no la he entendido, repítela por favor. Escribe 'preguntas' para ver ejemplos.")
        return

    opcion = personajes[personaje_seleccionado][elegida]
    asked_value = None
    is_match = False

    # Lógica de elecciones
    if elegida == 1:  # Sexo
        if "hombre" in escrito or "masculino" in escrito:
            if opcion == "masculino":
                messages.append("Sí, es un hombre.")
                asked_value = "masculino"
                is_match = True
            else:
                messages.append("No, no es un hombre.")
                asked_value = "masculino"
                is_match = False
        elif "mujer" in escrito or "femenino" in escrito:
            if opcion == "femenino":
                messages.append("Sí, es una mujer.")
                asked_value = "femenino"
                is_match = True
            else:
                messages.append("No, no es una mujer.")
                asked_value = "femenino"
                is_match = False

    if elegida == 2:  # Color de pelo
        if "negro" in escrito:
            if opcion == "negro":
                messages.append("Sí, su color de pelo es negro.")
                asked_value = "negro"
                is_match = True
            else:
                messages.append("No, su color de pelo no es negro.")
                asked_value = "negro"
                is_match = False
        elif "rubio" in escrito or "rubia" in escrito:
            if opcion == "rubio":
                messages.append("Sí, su color de pelo es rubio.")
                asked_value = "rubio"
                is_match = True
            else:
                messages.append("No, su color de pelo no es rubio.")
                asked_value = "rubio"
                is_match = False
        elif "pelirrojo" in escrito:
            if opcion == "pelirrojo":
                messages.append("Sí, su color de pelo es pelirrojo.")
                asked_value = "pelirrojo"
                is_match = True
            else:
                messages.append("No, su color de pelo no es pelirrojo.")
                asked_value = "pelirrojo"
                is_match = False

    if elegida == 3:  # Longitud de pelo
        if "corto" in escrito:
            if opcion == "corto":
                messages.append("Sí, tiene el pelo corto.")
                asked_value = "corto"
                is_match = True
            else:
                messages.append("No, no tiene el pelo corto.")
                asked_value = "corto"
                is_match = False
        elif "largo" in escrito:
            if opcion == "largo":
                messages.append("Sí, tiene el pelo largo.")
                asked_value = "largo"
                is_match = True
            else:
                messages.append("No, no tiene el pelo largo.")
                asked_value = "largo"
                is_match = False
        elif "calvo" in escrito:
            if opcion == "calvo":
                messages.append("Sí, está calvo.")
                asked_value = "calvo"
                is_match = True
            else:
                messages.append("No, no está calvo.")
                asked_value = "calvo"
                is_match = False

    if elegida == 4:  # Estilo de pelo
        if "rizado" in escrito:
            if opcion == "rizado":
                messages.append("Sí, tiene el pelo rizado.")
                asked_value = "rizado"
                is_match = True
            else:
                messages.append("No, no tiene el pelo rizado.")
                asked_value = "rizado"
                is_match = False
        elif "liso" in escrito:
            if opcion == "liso":
                messages.append("Sí, tiene el pelo liso.")
                asked_value = "liso"
                is_match = True
            else:
                messages.append("No, no tiene el pelo liso.")
                asked_value = "liso"
                is_match = False

    if elegida == 5:  # Color de ojos
        if "azul" in escrito or "azules" in escrito:
            if opcion == "azules":
                messages.append("Sí, tiene los ojos azules.")
                asked_value = "azules"
                is_match = True
            else:
                messages.append("No, no tiene los ojos azules.")
                asked_value = "azules"
                is_match = False
        elif "verdes" in escrito:
            if opcion == "verdes":
                messages.append("Sí, tiene los ojos verdes.")
                asked_value = "verdes"
                is_match = True
            else:
                messages.append("No, no tiene los ojos verdes.")
                asked_value = "verdes"
                is_match = False
        elif "marrones" in escrito or "marron" in escrito:
            if opcion == "marrones":
                messages.append("Sí, tiene los ojos marrones.")
                asked_value = "marrones"
                is_match = True
            else:
                messages.append("No, no tiene los ojos marrones.")
                asked_value = "marrones"
                is_match = False

    if elegida == 6:  # Barba
        if opcion == True:
            messages.append("Sí, tiene barba.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene barba.")
            asked_value = True
            is_match = False

    if elegida == 7:  # Bigote
        if opcion == True:
            messages.append("Sí, tiene bigote.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene bigote.")
            asked_value = True
            is_match = False

    if elegida == 8:  # Pecas
        if opcion == True:
            messages.append("Sí, tiene pecas.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene pecas.")
            asked_value = True
            is_match = False

    if elegida == 9:  # Gafas
        if opcion == True:
            messages.append("Sí, tiene gafas.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene gafas.")
            asked_value = True
            is_match = False

    if elegida == 10:  # Sombrero
        if opcion == True:
            messages.append("Sí, tiene sombrero.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene sombrero.")
            asked_value = True
            is_match = False

    if elegida == 11:  # Gorra
        if opcion == True:
            messages.append("Sí, tiene gorra.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene gorra.")
            asked_value = True
            is_match = False

    if elegida == 12:  # Diadema
        if opcion == True:
            messages.append("Sí, tiene diadema.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene diadema.")
            asked_value = True
            is_match = False

    if elegida == 13:  # Pendientes
        if opcion == True:
            messages.append("Sí, tiene pendientes.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene pendientes.")
            asked_value = True
            is_match = False

    if elegida == 14:  # Bufanda
        if opcion == True:
            messages.append("Sí, tiene bufanda.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene bufanda.")
            asked_value = True
            is_match = False

    if elegida == 15:  # Color de ropa
        if "azul" in escrito:
            if opcion == "azul":
                messages.append("Sí, su color de ropa es azul.")
                asked_value = "azul"
                is_match = True
            else:
                messages.append("No, su color de ropa no es azul.")
                asked_value = "azul"
                is_match = False
        elif "rojo" in escrito or "roja" in escrito:
            if opcion == "rojo":
                messages.append("Sí, su color de ropa es rojo.")
                asked_value = "rojo"
                is_match = True
            else:
                messages.append("No, su color de ropa no es rojo.")
                asked_value = "rojo"
                is_match = False
        elif "amarillo" in escrito or "amarilla" in escrito:
            if opcion == "amarillo":
                messages.append("Sí, su color de ropa es amarillo.")
                asked_value = "amarillo"
                is_match = True
            else:
                messages.append("No, su color de ropa no es amarillo.")
                asked_value = "amarillo"
                is_match = False
        elif "negro" in escrito or "negra" in escrito:
            if opcion == "negro":
                messages.append("Sí, su color de ropa es negro.")
                asked_value = "negro"
                is_match = True
            else:
                messages.append("No, su color de ropa no es negro.")
                asked_value = "negro"
                is_match = False

    if elegida == 16:  # Chaqueta
        if opcion == True:
            messages.append("Sí, tiene chaqueta.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene chaqueta.")
            asked_value = True
            is_match = False

    if elegida == 17:  # Corbata
        if opcion == True:
            messages.append("Sí, tiene corbata.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene corbata.")
            asked_value = True
            is_match = False

    if elegida == 18:  # Expresión
        if "serio" in escrito or "seria" in escrito:
            if opcion == "serio":
                messages.append("Sí, su expresión es seria.")
                asked_value = "serio"
                is_match = True
            else:
                messages.append("No, su expresión no es seria.")
                asked_value = "serio"
                is_match = False
        elif "sonriendo" in escrito:
            if opcion == "sonriendo":
                messages.append("Sí, su expresión es sonriendo.")
                asked_value = "sonriendo"
                is_match = True
            else:
                messages.append("No, su expresión no es sonriendo.")
                asked_value = "sonriendo"
                is_match = False
        elif "enfadado" in escrito:
            if opcion == "enfadado":
                messages.append("Sí, su expresión es enfadado.")
                asked_value = "enfadado"
                is_match = True
            else:
                messages.append("No, su expresión no es enfadado.")
                asked_value = "enfadado"
                is_match = False
        elif "asustado" in escrito:
            if opcion == "asustado":
                messages.append("Sí, su expresión es asustado.")
                asked_value = "asustado"
                is_match = True
            else:
                messages.append("No, su expresión no es asustado.")
                asked_value = "asustado"
                is_match = False

    if elegida == 19:  # Cejas
        if "gruesas" in escrito:
            if opcion == "gruesas":
                messages.append("Sí, tiene las cejas gruesas.")
                asked_value = "gruesas"
                is_match = True
            else:
                messages.append("No, no tiene las cejas gruesas.")
                asked_value = "gruesas"
                is_match = False
        elif "finas" in escrito:
            if opcion == "finas":
                messages.append("Sí, tiene las cejas finas.")
                asked_value = "finas"
                is_match = True
            else:
                messages.append("No, no tiene las cejas finas.")
                asked_value = "finas"
                is_match = False

    if elegida == 20:  # Edad
        if "joven" in escrito:
            if opcion == "joven":
                messages.append("Sí, es joven.")
                asked_value = "joven"
                is_match = True
            else:
                messages.append("No, no es joven.")
                asked_value = "joven"
                is_match = False
        elif "niño" in escrito:
            if opcion == "niño":
                messages.append("Sí, es un niño.")
                asked_value = "niño"
                is_match = True
            else:
                messages.append("No, no es un niño.")
                asked_value = "niño"
                is_match = False
        elif "viejo" in escrito:
            if opcion == "viejo":
                messages.append("Sí, es viejo.")
                asked_value = "viejo"
                is_match = True
            else:
                messages.append("No, no es viejo.")
                asked_value = "viejo"
                is_match = False

    if elegida == 21:  # Tatuajes
        if opcion == True:
            messages.append("Sí, tiene tatuajes.")
            asked_value = True
            is_match = True
        else:
            messages.append("No, no tiene tatuajes.")
            asked_value = True
            is_match = False

    # Filtrar personajes restantes
    if asked_value is not None:
        new_remaining = []
        for r in remaining:
            r_value = personajes[r][elegida]
            if is_match:
                if r_value == asked_value:
                    new_remaining.append(r)
            else:
                if r_value != asked_value:
                    new_remaining.append(r)
        remaining = new_remaining
        if len(remaining) == 1:
            name = personajes[remaining[0]][0]
            messages.append(f"Muy bien el personaje a adivinar era {name}\nHas ganado!!, si quieres terminar la partida escribe 'salir'.")
            user_text = ''  # Limpiar el input para la nueva instrucción

# Bucle principal
running = True
while running:
    WIDTH, HEIGHT = screen.get_size()
    remaining_height = max(1, HEIGHT - messages_y_start - 5)
    max_messages = max(1, remaining_height // line_height)

    screen.fill((255, 255, 255))

    for char in personajes:
        x, y = positions[char]
        screen.blit(char_images[char], (x, y))
        if char not in remaining:
            overlay = pygame.Surface((img_size, img_size))
            overlay.fill((128, 128, 128))
            overlay.set_alpha(128)
            screen.blit(overlay, (x, y))
            pygame.draw.line(screen, (255, 0, 0), (x, y), (x + img_size, y + img_size), 7)
            pygame.draw.line(screen, (255, 0, 0), (x + img_size, y), (x, y + img_size), 7)

    input_surface = pygame.Surface((WIDTH - 20, input_height))
    input_surface.fill((180, 180, 180))
    screen.blit(input_surface, (10, input_y))
    input_text = font.render("Pregunta: " + user_text, True, (255, 255, 255))
    pygame.draw.rect(screen, (0, 0, 0), (15, input_y + 5, input_text.get_width() + 10, input_text.get_height() + 5), 2)
    screen.blit(input_text, (20, input_y + 10))

    message_bg = pygame.Surface((WIDTH - 20, remaining_height))
    message_bg.fill((255, 255, 255))
    screen.blit(message_bg, (10, messages_y_start))

    for i, msg in enumerate(messages[-max_messages:]):
        text = small_font.render(msg, True, (0, 0, 0))
        screen.blit(text, (15, messages_y_start + i * line_height))

    pygame.display.flip()
    clock.tick(30)

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.VIDEORESIZE:
            WIDTH, HEIGHT = event.w, event.h
            screen = pygame.display.set_mode((WIDTH, HEIGHT), pygame.RESIZABLE | pygame.FULLSCREEN)
            col_count = max(5, (WIDTH - spacing) // (min_img_size + spacing))  # Recalcular col_count
            row_count = (num_chars - 1) // col_count + 1
            img_size = min((WIDTH - (col_count + 1) * spacing) // col_count, (HEIGHT * 6 // 10 - (row_count + 1) * spacing) // row_count)
            for i, char in enumerate(sorted(personajes.keys())):
                img = pygame.image.load(f"{char}.png")
                img = pygame.transform.scale(img, (img_size, img_size))
                char_images[char] = img
                col = i % col_count
                row = i // col_count
                x = col * (img_size + spacing) + spacing
                y = row * (img_size + spacing) + spacing
                positions[char] = (x, y)
            board_height = row_count * (img_size + spacing) + spacing
            input_y = board_height
            messages_y_start = input_y + input_height + 5
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_RETURN:
                if user_text.strip():
                    process_input(user_text)
                user_text = ''
            elif event.key == pygame.K_BACKSPACE:
                user_text = user_text[:-1]
            else:
                user_text += event.unicode

pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 684
#     682 running = True
#     683 while running:
# --> 684     WIDTH, HEIGHT = screen.get_size()
#     685     remaining_height = max(1, HEIGHT - messages_y_start - 5)
#     686     max_messages = max(1, remaining_height // line_height)
#
# error: display Surface quit
